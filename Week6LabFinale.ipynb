# %% [markdown]
# <a href="https://colab.research.google.com/github/zabl-en87/E11-Noel-Moreno-Marwan-Chris/blob/main/Week6LabFinale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
graphOut = pd.read_csv('/content/outside.csv')
graphIn = pd.read_csv('/content/test.csv')

cutOut = 240
concOut = graphOut.iloc[cutOut:,1]
concIn = graphIn.iloc[cutOut:,1]
part3Out = graphOut.iloc[cutOut:,2]
part25In = graphIn.iloc[cutOut:,5]
part25Out = graphOut.iloc[cutOut:,5]
part3In = graphIn.iloc[cutOut:,2]
tempOut = graphOut.iloc[cutOut:,9]
tempIn = graphIn.iloc[cutOut:,9]
gasOut = graphOut.iloc[cutOut:,10]
gasIn = graphIn.iloc[cutOut:,10]
relHumOut = graphOut.iloc[cutOut:,11]
relHumIn = graphIn.iloc[cutOut:,11]
presOut = graphOut.iloc[cutOut:,12]
presIn = graphIn.iloc[cutOut:,12]
altOut = graphOut.iloc[cutOut:,13]
altIn = graphIn.iloc[cutOut:,13]

timeOut = graphOut.iloc[:,8]
timeIn = graphIn.iloc[:,8]

print(concOut)
# Out:
# 240    0
# 241    0
# 242    0
# 243    0
# 244    0
#       ..
# 595    0
# 596    0
# 597    0
# 598    0
# 599    0
# Name: concentration, Length: 360, dtype: int64

# %%
plt.figure()
plt.hist(tempIn, 50)

plt.title('Inside Temperature')
plt.ylabel('Frecuency')
plt.xlabel('Temperature in Celsius')
plt.show()

plt.figure()
plt.hist(tempOut, 50)
plt.title('Outside Temperature')
plt.ylabel('Frecuency')
plt.xlabel('Temperature in Celsius')
plt.show()

# %%
plt.figure()
plt.hist(concIn, 50)

plt.title('Inside Particle Concentration')
plt.ylabel('Frecuency')
plt.xlabel('Amount of Particles')
plt.show()

plt.figure()
plt.hist(concOut, 50)
plt.title('Outside Particle Concentration')
plt.ylabel('Frecuency')
plt.xlabel('Amount of Particles')
plt.show()

# %%
plt.figure()
plt.hist(part3In, 25)

plt.title('Inside Particle 2.5')
plt.ylabel('Frecuency')
plt.xlabel('Number of Particles')
plt.show()

plt.figure()
plt.hist(part3Out, 50)
plt.title('Outside Particle 2.5')
plt.ylabel('Frecuency')
plt.xlabel('Number of Particles')
plt.show()

# %%
plt.figure()
plt.hist(part25In, 50)

plt.title('Inside Particle 25')
plt.ylabel('Frecuency')
plt.xlabel('Amount of Particles')
plt.show()

plt.figure()
plt.hist(part25Out, 50)
plt.title('Outside Particle 25')
plt.ylabel('Frecuency')
plt.xlabel('Amount of Particles')
plt.show()

# %%
plt.figure()
plt.hist(gasIn, 50)

plt.title('Inside Gas')
plt.ylabel('Frecuency')
plt.xlabel('Amount of Gas')
plt.show()

plt.figure()
plt.hist(gasOut, 12)
plt.title('Outside Gas')
plt.ylabel('Frecuency')
plt.xlabel('Amount of Gas')
plt.show()

# %%
plt.figure()
plt.hist(relHumIn, 50)

plt.title('Inside Relative Humidity')
plt.ylabel('Frecuency')
plt.xlabel('Humidity')
plt.show()

plt.figure()
plt.hist(relHumOut, 50)
plt.title('Outside Humidity')
plt.ylabel('Frecuency')
plt.xlabel('Humidity')
plt.show()

# %%
plt.figure()
plt.hist(presIn, 50)

plt.title('Inside Pressure')
plt.ylabel('Frecuency')
plt.xlabel('Pressure pascal')
plt.show()

plt.figure()
plt.hist(presOut, 50)
plt.title('Outside Pressure')
plt.ylabel('Frecuency')
plt.xlabel('Pressure pascal')
plt.show()

# %%
plt.figure()
plt.hist(altIn, 50)

plt.title('Inside Altitude')
plt.ylabel('Frecuency')
plt.xlabel('Altitude (meters)')
plt.show()

plt.figure()
plt.hist(altOut, 50)
plt.title('Outside Altitude')
plt.ylabel('Frecuency')
plt.xlabel('Altitude (meters)')
plt.show()

# %% [markdown]
# cutOut = 240
# concOut = graphOut.iloc[cutOut:,1]
# concIn = graphIn.iloc[cutOut:,1]
# part3Out = graphOut.iloc[cutOut:,2]
# part25In = graphIn.iloc[cutOut:,5]
# part25Out = graphOut.iloc[cutOut:,5]
# part3In = graphIn.iloc[cutOut:,2]
# tempOut = graphOut.iloc[cutOut:,9]
# tempIn = graphIn.iloc[cutOut:,9]
# gasOut = graphOut.iloc[cutOut:,10]
# gasIn = graphIn.iloc[cutOut:,10]
# relHumOut = graphOut.iloc[cutOut:,11]
# relHumIn = graphIn.iloc[cutOut:,11]
# presOut = graphOut.iloc[cutOut:,12]
# presIn = graphIn.iloc[cutOut:,12]
# altOut = graphOut.iloc[cutOut:,13]
# altIn = graphIn.iloc[cutOut:,13]
#
# timeOut = graphOut.iloc[:,8]
# timeIn = graphIn.iloc[:,8]
#
# print(concOut)

# %%
import numpy as np
np.mean(concOut)
np.std(concOut)

insideData = [concIn, part3In, part25In, tempIn, gasIn, relHumIn, presIn, altIn]
outsideData = [concOut, part3Out, part25Out, tempOut, gasOut, relHumOut, presOut, altOut]

insideMeanStat = [0,0,0,0,0,0,0,0]
outsideMeanStat = [0,0,0,0,0,0,0,0]

insideSDStat = [0,0,0,0,0,0,0,0]
outsideSDStat = [0,0,0,0,0,0,0,0]

sampleNum = 600 - cutOut

for i in range(0,8):
  insideMeanStat[i] = float(np.mean(insideData[i]))
  outsideMeanStat[i] = float(np.mean(outsideData[i]))

  insideSDStat[i] = float(np.std(insideData[i]))
  outsideSDStat[i] = float(np.std(outsideData[i]))

print(outsideSDStat)
print(insideSDStat)

print(outsideMeanStat)
print(insideMeanStat)
# Out:
# [5.458835854730271, 311.7048415791588, 7.713286196597165, 1.006450659005833, 0.0, 3.50702388177598, 0.04323042034795915, 0.3632324281687408]
# [0.0, 18.76897373326527, 0.0, 0.46750218031054896, 18650.734509135225, 0.5585355686371957, 0.02178528655827397, 0.18294146459242558]
# [1.3666666666666667, 128.74166666666667, 2.6277777777777778, 15.08144585503472, 12917167.0, 50.49491761018736, 1001.8444557084512, 95.39466471812106]
# [0.0, 10.775, 0.0, 28.966727973090276, 122971.44444444444, 26.47904176330579, 1002.5548341179962, 89.42752635773685]

# %%
#finding uncertainty

insideMeanUncertainty = [0,0,0,0,0,0,0,0]
outsideMeanUncertainty = [0,0,0,0,0,0,0,0]

for i in range(0,8):

  insideMeanUncertainty[i] = float(insideSDStat[i]/np.sqrt(sampleNum))


  outsideMeanUncertainty[i] = float(outsideSDStat[i]/np.sqrt(sampleNum))
print(insideMeanUncertainty)
print(outsideMeanUncertainty)
# Out:
# [0.0, 0.9892117723498645, 0.0, 0.02463952834793431, 982.9800180661631, 0.02943740918518077, 0.0011481854167266043, 0.009641861776651866]
# [0.28770591123232825, 16.42828761820163, 0.40652587709973903, 0.053044607250598154, 0.0, 0.1848363879169529, 0.002278443208433996, 0.019144029884112075]

# %%
#Number of std deviations away (from outside and inside)

import math

#Using smallest standard deviation

differenceSD = [0,0,0,0,0,0,0,0]

for i in range(0,8):
  if (insideSDStat[i] < outsideSDStat[i]) and insideSDStat[i] != 0.0:

    differenceSD[i] = float(np.abs((insideMeanStat[i] - outsideMeanStat[i])/insideSDStat[i]))

  if outsideSDStat[i] != 0.0:

    differenceSD[i] = float(np.abs((insideMeanStat[i] - outsideMeanStat[i])/outsideSDStat[i]))

  else:
    differenceSD[i] = 999

print(differenceSD)
# Out:
# [0.2503586301248466, 0.3784563180636657, 0.34068200126387926, 13.796286975231718, 999, 6.847936214999417, 16.432373403432265, 16.427878949211436]

# %% [markdown]
# Some data points are roughly the same, while others are so dramatically different that there is undeniable evidence that outside is in fact different from the inside.
#
# I do not think we took enough data points to get a gaussian distribution.

# %%
#Step 2, Comparing Sensors

graphOutComp= pd.read_csv('/content/outsideCompare.csv')
graphInComp = pd.read_csv('/content/insideCompare.csv')

# %%
cutOutComp = 0

part3OutComp = graphOutComp.iloc[cutOutComp:,7]
part25InComp = graphInComp.iloc[cutOutComp:,10]
part25OutComp = graphOutComp.iloc[cutOutComp:,10]
part3InComp = graphInComp.iloc[cutOutComp:,7]

tempOutComp = graphOutComp.iloc[cutOutComp:,13]
tempInComp = graphInComp.iloc[cutOutComp:,13]
gasOutComp = graphOutComp.iloc[cutOutComp:,14]
gasInComp = graphInComp.iloc[cutOutComp:,14]
relHumOutComp = graphOutComp.iloc[cutOutComp:,15]
relHumInComp = graphInComp.iloc[cutOutComp:,15]
presOutComp = graphOutComp.iloc[cutOutComp:,16]
presInComp = graphInComp.iloc[cutOutComp:,16]
altOutComp = graphOutComp.iloc[cutOutComp:,17]
altInComp = graphInComp.iloc[cutOutComp:,17]

# %%
plt.figure()
plt.hist(tempIn, 50)

plt.title('Our Inside Temperature')
plt.ylabel('Frecuency')
plt.xlabel('Temperature in Celsius')
plt.show()

plt.figure()
plt.hist(tempInComp, 50)
plt.title('Compare Outside Temperature')
plt.ylabel('Frecuency')
plt.xlabel('Temperature in Celsius')
plt.show()

# %%
plt.figure()
plt.hist(tempOut, 50)

plt.title('Our outside Temperature')
plt.ylabel('Frecuency')
plt.xlabel('Temperature in Celsius')
plt.show()

plt.figure()
plt.hist(tempOutComp, 50)
plt.title('Compare Outside Temperature')
plt.ylabel('Frecuency')
plt.xlabel('Temperature in Celsius')
plt.show()

# %%
plt.figure()
plt.hist(part3In, 15)

plt.title('Our Inside 3 Particles')
plt.ylabel('Frecuency')
plt.xlabel('Number of Particles')
plt.show()

plt.figure()
plt.hist(part3InComp, 15)
plt.title('Compare Inside 3 Particles')
plt.ylabel('Frecuency')
plt.xlabel('Number of Particles')
plt.show()

# %%
plt.figure()
plt.hist(part3Out, 25)

plt.title('Our Outside 25 Particles')
plt.ylabel('Frecuency')
plt.xlabel('Number of Particles')
plt.show()

plt.figure()
plt.hist(part3OutComp, 10)
plt.title('Compare Outside 25 Particles')
plt.ylabel('Frecuency')
plt.xlabel('Number of Particles')
plt.show()

# %%
plt.figure()
plt.hist(gasIn, 50)

plt.title('Our Inside Gas')
plt.ylabel('Frecuency')
plt.xlabel('Amount of Gas')
plt.show()

plt.figure()
plt.hist(gasInComp, 50)
plt.title('Compare Inside Gas')
plt.ylabel('Frecuency')
plt.xlabel('Amount of Gas')
plt.show()

# %%
plt.figure()
plt.hist(gasOut, 50)

plt.title('Our Outside Gas')
plt.ylabel('Frecuency')
plt.xlabel('Amount of Gas')
plt.show()

plt.figure()
plt.hist(tempOut, 50)
plt.title('Compare Outside Gas')
plt.ylabel('Frecuency')
plt.xlabel('Amount of Gas')
plt.show()

# %%
plt.figure()
plt.hist(relHumIn, 50)

plt.title('Our Relative Humidity Inside')
plt.ylabel('Frecuency')
plt.xlabel('Humidity')
plt.show()

plt.figure()
plt.hist(relHumInComp, 50)
plt.title('Compare Relative Humidity Inside')
plt.ylabel('Frecuency')
plt.xlabel('Humidity')
plt.show()

# %%
plt.figure()
plt.hist(relHumOut, 50)

plt.title('Our Relative Humidity Outside')
plt.ylabel('Frecuency')
plt.xlabel('Humidity')
plt.show()

plt.figure()
plt.hist(relHumOutComp, 50)
plt.title('Compare Relative Humidity Outside')
plt.ylabel('Frecuency')
plt.xlabel('Humidity')
plt.show()

# %%
plt.figure()
plt.hist(presIn, 50)

plt.title('Our Pressure Inside')
plt.ylabel('Frecuency')
plt.xlabel('Pressure (pascal)')
plt.show()

plt.figure()
plt.hist(presInComp, 50)
plt.title('Compare Pressure Inside')
plt.ylabel('Frecuency')
plt.xlabel('Pressure (pascal)')
plt.show()

# %%
plt.figure()
plt.hist(presOut, 50)

plt.title('Our Pressure Outside')
plt.ylabel('Frecuency')
plt.xlabel('Pressure (pascal)')
plt.show()

plt.figure()
plt.hist(presOutComp, 50)
plt.title('Compare Pressure Outside')
plt.ylabel('Frecuency')
plt.xlabel('Pressure (pascal)')
plt.show()

# %%
plt.figure()
plt.hist(altIn, 50)

plt.title('Our Altitude Inside')
plt.ylabel('Frecuency')
plt.xlabel('Altitude (meters)')
plt.show()

plt.figure()
plt.hist(altInComp, 50)
plt.title('Compare Altitude Inside')
plt.ylabel('Frecuency')
plt.xlabel('Altitude (meters)')
plt.show()

# %%
plt.figure()
plt.hist(altOut, 50)

plt.title('Our Altitude Outside')
plt.ylabel('Frecuency')
plt.xlabel('Altitude (meters)')
plt.show()

plt.figure()
plt.hist(altOutComp, 50)
plt.title('Compare Altitude Outside')
plt.ylabel('Frecuency')
plt.xlabel('Altitude (meters)')
plt.show()

# %% [markdown]
# Just by looking at the graphs, the sensor of the group we got data to compare too seems to be broken. This is because it detects an unreal number in various graphs. One such example is the comparison data measuring almost 3000 meters of altitude above sea level despite only walking around with their sensor. Any great comparison of data is not neccesary as we do not have accurate information to tell us what information to look at.

# %% [markdown]
# Part 3, dirty data:

# %%
#graphOut

graphDirt = pd.read_csv('/content/dataDirty.csv')

label = ['concentration','particle03','particle25','Temperature','Gas','Relative Humidity','Pressure','Altitude']

dirtCut = 60
concDirt = graphDirt.iloc[dirtCut:,1]
part3Dirt = graphDirt.iloc[dirtCut:,2]
part25Dirt = graphDirt.iloc[dirtCut:,5]
tempDirt = graphDirt.iloc[dirtCut:,9]
gasDirt = graphDirt.iloc[dirtCut:,10]
relHumDirt = graphDirt.iloc[dirtCut:,11]
presDirt = graphDirt.iloc[dirtCut:,12]
altDirt = graphDirt.iloc[dirtCut:,13]
timeDirt = graphDirt.iloc[dirtCut:,8]

varDirt = [concDirt,part3Dirt,part25Dirt,tempDirt,gasDirt,relHumDirt,presDirt,altDirt,timeDirt]
print(label[1])
# Out:
# particle03

# %%
plt.figure()
plt.hist(varDirt[0],25)

plt.title("Dirt Data")
plt.xlabel('Amount')
plt.ylabel('Frecuency')
print(label[0])
plt.show()

plt.figure()
plt.hist(concOut,25)
plt.title("Outside Normal")
plt.xlabel("Number of Particles")
plt.ylabel("Frecuency")
plt.show()
# Out:
# concentration

# %%
plt.figure()
plt.hist(varDirt[1],25)

plt.title("Outside Dirty")
plt.xlabel('Number of part 03 Particles')
plt.ylabel('Frecuency')
print(label[1])
plt.show()

plt.figure()
plt.hist(part3Out,25)
plt.title("Outside Normal")
plt.xlabel("Number of part 03 Particles")
plt.ylabel("Frecuency")
plt.show()
# Out:
# particle03

# %%
plt.figure()
plt.hist(varDirt[2],25)

plt.title("Outside Dirt")
plt.xlabel('Amount of part 25 Particles')
plt.ylabel('Frecuency')
print(label[2])
plt.show()

plt.figure()
plt.hist(part25Out,25)
plt.title("Outside Normal")
plt.xlabel("Number of part 25 Particles")
plt.ylabel("Frecuency")
plt.show()
# Out:
# particle25

# %%
plt.figure()
plt.hist(varDirt[3],25)

plt.title("Dirt Data")
plt.xlabel('Temperature Celcius')
plt.ylabel('Frecuency')
print(label[3])
plt.show()

plt.figure()
plt.hist(tempOut,25)
plt.title("Outside Normal")
plt.xlabel("Temperature Celsius")
plt.ylabel("Frecuency")
plt.show()
# Out:
# Temperature

# %%
plt.figure()
plt.hist(varDirt[4],25)

plt.title("Dirt Data")
plt.xlabel('Amount of Gas')
plt.ylabel('Frecuency')
print(label[4])
plt.show()

plt.figure()
plt.hist(gasOut,10)
plt.title("Outside Normal")
plt.xlabel("Amount of Gas")
plt.ylabel("Frecuency")
plt.show()
# Out:
# Gas

# %%
plt.figure()
plt.hist(varDirt[5],25)

plt.title("Dirt Data")
plt.xlabel('Relative Humidity')
plt.ylabel('Frecuency')
print(label[5])
plt.show()

plt.figure()
plt.hist(relHumOut,25)
plt.title("Outside Normal")
plt.xlabel("Relative Humidity")
plt.ylabel("Frecuency")
plt.show()
# Out:
# Relative Humidity

# %%
plt.figure()
plt.hist(varDirt[6],25)

plt.title("Dirt Data")
plt.xlabel('Pressure')
plt.ylabel('Frecuency')
print(label[6])
plt.show()

plt.figure()
plt.hist(presOut,25)
plt.title("Outside Normal")
plt.xlabel("Pressure")
plt.ylabel("Frecuency")
plt.show()
# Out:
# Pressure

# %%
plt.figure()
plt.hist(varDirt[7],25)

plt.title("Dirt Data")
plt.xlabel('Altitude Meters')
plt.ylabel('Frecuency')
print(label[7])
plt.show()

plt.figure()
plt.hist(altOut,25)
plt.title("Outside Normal")
plt.xlabel("Altitude Meters")
plt.ylabel("Frecuency")
plt.show()
# Out:
# Altitude

# %% [markdown]
# Part 4: Correlations in Data.

# %%
plt.figure()
plt.plot(tempDirt,relHumDirt)
plt.title("Correlation Graph: Temperature vs. Relative Humidity")
plt.ylabel("Relative Humidity")
plt.xlabel("Temperature")
plt.show()

# %% [markdown]
# Just by looking at the graph, I can see that as temperature increases, the relative humidity decreases. This is quite surprising as I thought that more humid areas on earth tend to be hotter.
#
# By looking at the graph I can see that temperature and relative humidity seem to be inversely, and linearly dependent on one another.

# %%
plt.figure()
plt.plot(tempDirt,altDirt)
plt.title("Correlation Graph: Temperature vs. Altitude")
plt.ylabel("Altitude")
plt.xlabel("Temperature")
plt.show()

# %% [markdown]
# I see no correlation whatsoever between temperature and altitude. Probable because I didn't go up or down when outside.

# %%
plt.figure()
plt.plot(tempDirt,presDirt)
plt.title("Correlation Graph: Temperature vs. Pressure")
plt.ylabel("Pressure")
plt.xlabel("Temperature")
plt.show()

# %% [markdown]
# I can make no conclusive evidence that these two variables are related. (No correlation whatsoever).

# %%
plt.figure()
plt.plot(tempDirt,gasDirt)
plt.title("Correlation Graph: Temperature vs. Gas")
plt.ylabel("Gas")
plt.xlabel("Temperature")
plt.show()

# %% [markdown]
# This comparison, I can a correlation between the amount of gas, and the temperature. As temperature increases, I see that gas decreases after a certain temperature. Though I can see many outliers within this data set.

# %%
plt.figure()
plt.plot(tempDirt,part3Dirt)
plt.title("Correlation Graph: Temperature vs. Particle 2.5")
plt.ylabel("Particle 2.5 Amount")
plt.xlabel("Temperature")
plt.show()

# %% [markdown]
# In the question in the lab, we are told to be careful and make sure that the time in both graphs are the same. We made sure that the time matched up, because we attached both sensors at the same time, and ran them alongside one another. For each index, or second that passed, we got data from each sensor at the exact same time, as viewed from the "Time" column in the outDirt.csv file. Looking at the graph, we can see a chaotic mess between temperature and the number of particles. When the temperature is relatively low, there is both high and lower amount of particles, while as temperature increases, the amount of particles seems stable to then only be chaotic again at around 23 degrees celsius.
